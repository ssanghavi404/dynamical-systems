# %%
import numpy as np

from plotting import *

# %%
plot(metrics={"Transformer":{'med': [1, 2, 3, 4, 2, 4, 2, 3, 4, 5, 2, 1, 5, 2, 3, 4, 5],
                                   'q1': [0, 1, 2, 3, 1, 3, 1, 2, 3, 4, 1, 0, 4, 1, 2, 3, 4],
                                   'q3': [2, 3, 4, 5, 2, 5, 3, 4, 6, 7, 3, 4, 6, 3, 4, 5, 6],
                                  },
                   },
    title="Plot")
# Out:
# (<Figure size 288x216 with 1 Axes>,
#  <AxesSubplot:title={'center':'Plot'}, xlabel='Timestep in Trajectory', ylabel='Median Error at Timestep'>)
